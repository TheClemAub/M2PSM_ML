# %% [markdown]
# ----
#
# <a
#   target="_blank" href="https://colab.research.google.com/drive/12W7jPdXUI9Nv8_JaynT8cVVN-QXkaViG">
#   <img src="https://www.tensorflow.org/images/colab_logo_32px.png" />
#   Ouvrir dans Google Colab
# </a>
#
# ----

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

x, y = make_regression(n_samples=50, n_features=1, noise=5)
plt.scatter(x, y)

b = np.linalg.inv(x.T.dot(x)).dot(x.T).dot(y)
y_calcule = x.dot(b)

plt.scatter(x,y)
plt.plot(x,y_calcule, color="green")

from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x,y)

y_calcule_ = model.predict(x)
plt.scatter(x, y)
plt.plot(x, y_calcule_, c='r')
plt.grid()
print('Précision du modèle : ', model.score(x,y)*100, '%')

a = model.coef_
b = model.intercept_
a = round(a[0],2)
b = round(b,2)
print('f(x) =', a, 'x +', b)
# Out:
# Précision du modèle :  50.81114033461238 %
# f(x) = 5.25 x + -0.03
